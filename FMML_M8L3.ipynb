# %% [markdown]
# <a href="https://colab.research.google.com/github/pravalika3986/FMML_MODULES/blob/main/FMML_M8L3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-15 05:28:16--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  84.5MB/s    in 0.8s
#
# 2025-03-15 05:28:20 (84.5 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 15865  1606.02891v2  We participated in the WMT 2016 shared news tr...    cs
# 9303    1203.4345v1  We propose a principled algorithm for robust B...    cs
# 33516   1405.6285v1  The past decade has seen the rapid development...    cs
# 37994   0906.2034v1  We use convex relaxation techniques to provide...  stat
# 28499  1706.08665v2  Video prediction has been an active topic of r...    cs
# ...             ...                                                ...   ...
# 29006  1708.02108v3  Weakly supervised semantic segmentation and lo...    cs
# 6699   1705.07025v2  Clinical notes are a rich source of informatio...  stat
# 26893  1701.02096v2  The recent work of Gatys et al., who character...    cs
# 5446    1210.5631v2  Many businesses are using recommender systems ...  stat
# 7969   1704.05761v2  This paper addresses maximum likelihood (ML) e...  stat
#
#                                                    title  year  \
# 15865  Edinburgh Neural Machine Translation Systems f...  2016
# 9303   Robust Filtering and Smoothing with Gaussian P...  2012
# 33516  Traversing News with Ant Colony Optimisation a...  2014
# 37994  Regularization methods for learning incomplete...  2009
# 28499  Hierarchical Model for Long-term Video Prediction  2017
# ...                                                  ...   ...
# 29006  Two-Phase Learning for Weakly Supervised Objec...  2017
# 6699   Learning Effective Representations from Clinic...  2017
# 26893  Improved Texture Networks: Maximizing Quality ...  2017
# 5446   Content-boosted Matrix Factorization Technique...  2012
# 7969   Maximum Likelihood Estimation based on Random ...  2017
#
#                                                 keywords
# 15865  [participated, translation, translation, direc...
# 9303   [principled, algorithm, filtering, smoothing, ...
# 33516  [development, published, surpassing, tradition...
# 37994  [relaxation, techniques, solutions, completion...
# 28499  [prediction, algorithms, predictions, generate...
# ...                                                  ...
# 29006  [supervised, segmentation, important, fundamen...
# 6699   [information, effectively, challenges, summari...
# 26893  [characterized, statistics, convolutional, gen...
# 5446   [businesses, recommender, marketing, recommend...
# 7969   [addresses, likelihood, estimation, extrasolar...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 15865    [participated, translation, translation, direc...
# 9303     [principled, algorithm, filtering, smoothing, ...
# 33516    [development, published, surpassing, tradition...
# 37994    [relaxation, techniques, solutions, completion...
# 28499    [prediction, algorithms, predictions, generate...
#                                ...
# 3731     [environments, partially, contextual, encompas...
# 20095    [introduces, abstractions, meaningful, compute...
# 4345     [probabilistic, generative, segmentation, part...
# 17620    [implements, sentiment, orientations, represen...
# 9478     [diagnosis, detection, classification, specifi...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8683 words.
# Out of those 4540 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c5e948dc-a454-4552-a2c6-7834f5cd5031" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c5e948dc-a454-4552-a2c6-7834f5cd5031")) {                    Plotly.newPlot(                        "c5e948dc-a454-4552-a2c6-7834f5cd5031",                        [{"x":["attentional","bidirectional","additional","translations","pervasive","translation","segmentation","participated","monolingual","evaluation","vocabulary","automatic","improvements","substantial","constrained","experimented","directions","algorithm","smoothers","filtering","principled","robustness","importance","evaluations","numerical","representing","nonlinear","probability","functions","transition","increasingly","increasing","processes","stochastic","distributions","processing","demonstrate","measurement","smoothing","estimates","identification","parametric","posterior","representation","described","situations","developed","optimisation","traditional","information","important","intelligence","hamiltonian","development","surpassing","available","documents","traversing","published","pheromone","consumption","newspapers","challenges","presented","newspaper","understand","production","regularization","relaxation","regularizer","efficient","completion","reconstruction","techniques","algorithms","iteratively","thresholded","minimizing","efficiently","incomplete","solutions","additionally","estimating","combination","hierarchical","predictions","predicted","convolutional","generates","prediction","realistic","adversarial","structure","conjugate","consequently","correlation","unobserved","parameterized","reinforcement","suboptimal","parameterization","logarithmically","complexity","logarithmic","significant","probabilities","parameter","observing","frequentist","particular","component","implement","reasonable","unfortunately","intrusion","communication","organizations","implementation","detections","benchmark","continues","implemented","parameters","performance","discussed","detection","approaches","progression","evolution","completely","reliability","diversity","strategies","classification","contribution","recognition","conventional","framework","cognitive","notoriously","difficult","sufficiently","synthetic","corresponding","unavailable","extracted","components","effectiveness","thoroughly","perception","experiments","potential","authentic","extensive","paintings","illustrate","transfers","portraits","deconvolutional","converting","conducting","furthermore","discriminative","facilitate","consecutively","investigated","transferred","connected","optimization","applications","evaluated","statistically","segmenting","boundaries","biomedical","volumetric","automatically","simultaneous","optimized","smoothness","requiring","improvement","intervention","coherence","degeneration","tomography","including","validated","transformations","essential","quantitative","widespread","positioning","convolution","different","relations","underlying","empirical","empirically","correctly"],"y":[11,13,130,14,4,97,220,8,7,264,38,204,115,41,63,9,36,814,1,65,31,91,80,65,85,70,47,160,215,30,50,117,97,120,111,287,548,32,19,74,98,48,43,354,60,54,199,23,174,682,367,82,3,131,8,302,65,4,33,4,23,2,134,186,2,65,26,80,23,21,396,32,93,364,576,39,3,36,143,27,117,57,66,132,120,87,40,377,54,227,62,95,351,7,38,77,5,14,116,13,9,1,228,20,241,53,118,21,2,259,117,84,42,33,5,52,7,142,18,226,6,106,238,898,57,333,416,12,68,57,20,45,97,534,57,379,82,524,43,5,138,17,140,136,5,115,105,198,18,38,620,140,4,163,5,61,7,2,6,10,9,169,107,41,4,43,15,66,305,429,158,25,23,41,19,14,182,26,55,19,66,127,18,19,1,20,257,37,50,79,69,15,10,42,737,85,133,141,74,26],"type":"bar"},{"x":["attentional","bidirectional","additional","translati ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4540,), (4540, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8091666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Coresets</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Triangulation</span> <br/><br/><span style=''>Multiple</span> <span style=''>view</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>triangulation</span> <span style=''>by</span> <span style=''>ell</span> <span style=''>infty</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>minimisation</span> <span style=''>has</span> <span style=''>become</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>established</span> <span style=''>in</span> <span style=''>computer</span> <span style=''>vision</span> <span style=''>State</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>ell</span> <span style=''>infty</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>triangulation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>exploit</span> <span style=''>the</span> <span style=''>quasiconvexity</span> <span style=''>of</span> <span style=''>the</span> <span style=''>cost</span> <span style=''>function</span> <span style=''>to</span> <span style=''>derive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iterative</span> <span style=''>update</span> <span style=''>rules</span> <span style=''>that</span> <span style=''>deliver</span> <span style=''>the</span> <span style=''>global</span> <span style=''>minimum</span> <span style=''>Such</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>however</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3043478260869565);'>computationally</span> <span style=''>costly</span> <span style=''>for</span> <span style=''>large</span> <span style=''>problem</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>instances</span> <span style=''>that</span> <span style=''>contain</span> <span style=''>many</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>measurements</span> <span style=''>eg</span> <span style=''>from</span> <span style=''>web</span> <span style=''>based</span> <span style=''>photo</span> <span style=''>sharing</span> <span style=''>sites</span> <span style=''>or</span> <span style=''>long</span> <span style=''>term</span> <span style=''>video</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recordings</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>ell</span> <span style=''>infty</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>triangulation</span> <span style=''>admits</span> <span style=''>a</span> <span style=''>coreset</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>scheme</span> <span style=''>which</span> <span style=''>seeks</span> <span style=''>small</span> <span style='background-color:rgba(0, 255, 0, 0.393939393939394);'>representative</span> <span style=''>subsets</span> <span style=''>of</span> <span style=''>the</span> <span style=''>input</span> <span style=''>data</span> <span style=''>called</span> <span style=''>coresets</span> <span style=''>A</span> <span style=''>coreset</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>possesses</span> <span style=''>the</span> <span style=''>special</span> <span style=''>property</span> <span style=''>that</span> <span style=''>the</span> <span style=''>error</span> <span style=''>of</span> <span style=''>the</span> <span style=''>ell</span> <span style=''>infty</span> <span style=''>solution</span> <span style=''>on</span> <span style=''>the</span> <span style=''>coreset</span> <span style=''>is</span> <span style=''>within</span> <span style=''>known</span> <span style=''>bounds</span> <span style=''>from</span> <span style=''>the</ ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimized</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Algorithms</span> <span style=''>to</span> <span style=''>Sample</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Determinantal</span> <span style=''>Point</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technical</span> <span style=''>report</span> <span style=''>we</span> <span style=''>discuss</span> <span style=''>several</span> <span style=''>sampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Determinantal</span> <span style=''>Point</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Processes</span> <span style=''>(DPP)</span> <span style=''>DPPs</span> <span style=''>have</span> <span style=''>recently</span> <span style=''>gained</span> <span style=''>a</span> <span style=''>broad</span> <span style=''>interest</span> <span style=''>in</span> <span style=''>the</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>literature</span> <span style=''>as</span> <span style=''>random</span> <span style=''>point</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>with</span> <span style=''>negative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlation</span> <span style=''>ie</span> <span style=''>ones</span> <span style=''>that</span> <span style=''>can</span> <span style=''>generate</span> <span style=''>a</span> <span style=''>diverse</span> <span style=''>sample</span> <span style=''>from</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>items</span> <span style=''>They</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametrized</span> <span style=''>by</span> <span style=''>a</span> <span style=''>matrix</span> <span style=''>mathbfL</span> <span style=''>called</span> <span style=''>L</span> <span style=''>ensemble</span> <span style=''>that</span> <span style=''>encodes</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlations</span> <span style=''>between</span> <span style=''>items</span> <span style=''>The</span> <span style=''>standard</span> <span style=''>sampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>separated</span> <span style=''>in</span> <span style=''>three</span> <span style=''>phases</span> <span style=''>1eigendecomposition</span> <span style=''>of</span> <span style=''>mathbfL</span> <span style=''>2an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>eigenvector</span> <span style=''>sampling</span> <span style=''>phase</span> <span style=''>where</span> <span style=''>mathbfLs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>eigenvectors</span> <span style=''>are</span> <span style=''>sampled</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independently</span> <span style=''>via</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Bernoulli</span> <span style=''>variable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametrized</span> <span style=''>by</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>associated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>eigenvalue</span> <span style=''>3a</span> <span style=''>Gram</span> <span style=''>Schmidt</span> <span style=''>type</span> <span style=''>orthogonalisation</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Weak</span> <span style='background-color:rgba(255, 0, 0, 0.3413173652694611);'>Convergence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Properties</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Constrained</span> <span style=''>Emphatic</span> <span style=''>Temporal</span> <span style='background-color:rgba(0, 255, 0, 0.38636363636363635);'>difference</span> <span style=''>Learning</span> <span style=''>with</span> <span style=''>Constant</span> <span style=''>and</span> <span style=''>Slowly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Diminishing</span> <span style=''>Stepsize</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>emphatic</span> <span style=''>temporal</span> <span style='background-color:rgba(0, 255, 0, 0.38636363636363635);'>difference</span> <span style=''>(TD)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>ETD(lambda)</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>the</span> <span style=''>value</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.4400000000000001);'>stationary</span> <span style=''>policies</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666665);'>discounted</span> <span style=''>finite</span> <span style=''>state</span> <span style=''>and</span> <span style=''>action</span> <span style=''>Markov</span> <span style=''>decision</span> <span style=''>process</span> <span style=''>The</span> <span style=''>ETD(lambda)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>was</span> <span style=''>recently</span> <span style=''>proposed</span> <span style=''>by</span> <span style=''>Sutton</span> <span style=''>Mahmood</span> <span style=''>and</span> <span style=''>White</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>a</span> <span style=''>long</span> <span style=''>standing</span> <span style='background-color:rgba(255, 0, 0, 0.5733333333333335);'>divergence</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>the</span> <span style=''>standard</span> <span style=''>TD</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>when</span> <span style=''>it</span> <span style=''>is</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>off</span> <span style=''>policy</span> <span style=''>training</span> <span style=''>where</span> <span style=''>data</span> <span style=''>from</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploratory</span> <span style=''>policy</span> <span style=''>are</span> <span style=''>used</span> <span style=''>to</span> <span style=''>evaluate</span> <span style=''>other</span> <span style=''>policies</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>The</span> <span style=''>almost</span> <span style=''>sure</span> <span style='background-color:rgba(255, 0, 0, 0.3413173652694611);'>convergence</span> <span style=''>of</span> <span style=''>ETD(lambda)</span> <span style=''>has</span> <span style=''>been</span> <span style=''>proved</span> <span style=''>in</span> <span style=''>our</span> <span style=''>recent</span> <span style=''>work</span> <span style=''>under</span> <span style=''>general</span> <span style=''>off</span> <span style=''>policy</span> <span style=''>training</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>but</span> <span style=''>for</span> <span style=''>a</span> <span style=''>narrow</span> <span style=''>range</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diminishing</ ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Embedded</span> <span style=''>Real</span> <span style=''>Time</span> <span style=''>Fall</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Detection</span> <span style=''>Using</span> <span style=''>Deep</span> <span style=''>Learning</span> <span style=''>For</span> <span style=''>Elderly</span> <span style=''>Care</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>a</span> <span style=''>real</span> <span style=''>time</span> <span style=''>embedded</span> <span style=''>fall</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>system</span> <span style=''>using</span> <span style=''>a</span> <span style=''>DVS(Dynamic</span> <span style=''>Vision</span> <span style=''>Sensor)</span> <span style=''>that</span> <span style=''>has</span> <span style=''>never</span> <span style=''>been</span> <span style=''>used</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traditional</span> <span style=''>fall</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>a</span> <span style=''>dataset</span> <span style=''>for</span> <span style=''>fall</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>using</span> <span style=''>that</span> <span style=''>and</span> <span style=''>a</span> <span style=''>DVS</span> <span style=''>TN(DVS</span> <span style=''>Temporal</span> <span style=''>Network)</span> <span style=''>The</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contribution</span> <span style=''>is</span> <span style=''>building</span> <span style=''>a</span> <span style=''>DVS</span> <span style=''>Falls</span> <span style=''>Dataset</span> <span style=''>which</span> <span style=''>made</span> <span style=''>our</span> <span style=''>network</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recognize</span> <span style=''>a</span> <span style=''>much</span> <span style=''>greater</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>falls</span> <span style=''>than</span> <span style=''>the</span> <span style=''>existing</span> <span style=''>datasets</span> <span style=''>that</span> <span style=''>existed</span> <span style=''>before</span> <span style=''>and</span> <span style=''>solved</span> <span style=''>privacy</span> <span style=''>issues</span> <span style=''>using</span> <span style=''>the</span> <span style=''>DVS</span> <span style=''>Secondly</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style=''>DVS</span> <span style=''>TN</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimized</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>network</span> <span style=''>to</span> <span style=''>detect</span> <span style=''>falls</span> <span style=''>using</span> <span style=''>DVS</span> <span style=''>Finally</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implemented</span> <span style=''>a</span> <span style=''>fall</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>system</span> <span style=''>which</span> <span style=''>can</span> <span style=''>run</span> <span style=''>on</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computing</span> <span style=''>HW</span> <span style=''>with</span> <span style=''>real</span> <span style=''>time</span> <span style=''>and</span> <span style=''>tested</span> <span style=''>on</span> <span style=''>DVS</span> <span style=''>Falls</span> <span style=''>Dataset</span> <span style=''>that</span> <span style=''>takes</span> <span style=''>into</span> <span style=''>account</span> <span style=''>various</span> < ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.07236608726498758)
# 	knowledge (0.12380276693863072)
# 	processing (0.10180915218162469)
# 	information (0.24192976232706634)
# 	segmentation (0.07804185881518269)
# 	experimental (0.14012061014544164)
# 	detection (0.11812699538843562)
# 	different (0.261440227030862)
# 	convolutional (0.13373536715147216)
# 	recognition (0.13444483859524653)
#
# Some Statistics words are:
# 	variables (0.1413427561837456)
# 	stochastic (0.13679959616355375)
# 	statistical (0.15497223624432105)
# 	algorithm (0.3871781928319031)
# 	estimation (0.1701161029782938)
# 	distribution (0.18273599192327108)
# 	theoretical (0.1580010095911156)
# 	dimensional (0.18828874305906107)
# 	inference (0.20292781423523473)
# 	regression (0.18021201413427562)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="00bdb7c8-84f7-430a-ac2e-1c4924620399" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00bdb7c8-84f7-430a-ac2e-1c4924620399")) {                    Plotly.newPlot(                        "00bdb7c8-84f7-430a-ac2e-1c4924620399",                        [{"x":["attentional","bidirectional","additional","translations","pervasive","translation","segmentation","participated","monolingual","evaluation","vocabulary","automatic","improvements","substantial","constrained","experimented","directions","algorithm","smoothers","filtering","principled","robustness","importance","evaluations","numerical","representing","nonlinear","probability","functions","transition","increasingly","increasing","processes","stochastic","distributions","processing","demonstrate","measurement","smoothing","estimates","identification","parametric","posterior","representation","described","situations","developed","optimisation","traditional","information","important","intelligence","hamiltonian","development","surpassing","available","documents","traversing","published","pheromone","consumption","newspapers","challenges","presented","newspaper","understand","production","regularization","relaxation","regularizer","efficient","completion","reconstruction","techniques","algorithms","iteratively","thresholded","minimizing","efficiently","incomplete","solutions","additionally","estimating","combination","hierarchical","predictions","predicted","convolutional","generates","prediction","realistic","adversarial","structure","conjugate","consequently","correlation","unobserved","parameterized","reinforcement","suboptimal","parameterization","logarithmically","complexity","logarithmic","significant","probabilities","parameter","observing","frequentist","particular","component","implement","reasonable","unfortunately","intrusion","communication","organizations","implementation","detections","benchmark","continues","implemented","parameters","performance","discussed","detection","approaches","progression","evolution","completely","reliability","diversity","strategies","classification","contribution","recognition","conventional","framework","cognitive","notoriously","difficult","sufficiently","synthetic","corresponding","unavailable","extracted","components","effectiveness","thoroughly","perception","experiments","potential","authentic","extensive","paintings","illustrate","transfers","portraits","deconvolutional","converting","conducting","furthermore","discriminative","facilitate","consecutively","investigated","transferred","connected","optimization","applications","evaluated","statistically","segmenting","boundaries","biomedical","volumetric","automatically","simultaneous","optimized","smoothness","requiring","improvement","intervention","coherence","degeneration","tomography","including","validated","transformations","essential","quantitative","widespread","positioning","convolution","different","relations","underlying","empirical","empirically","correctly","estimation","stochasticity","simulations","approximations","generating","predictive","international","designing","interpretable","simulating","suppressing","compromise","diagnostic","incorporate","generative","preserving","structures","attracted","converges","denoising","attention","associated","compromises","especially","comparing","promising","introduces","simulated","reduction","extending","configurations","radiation","multiclass","performances","conditions","properties","misclassification","correction","asymptotic","difficulties","corrected","preferable","consistency","classifiers","dimension","introduce","contextual","dimensional","handcrafted","efficiency","extracting","intrinsic","frequently","regress ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	terminate
# 	horseshoe
# 	repertoires
# 	subsequence
# 	bonferroni
# 	exemplify
# 	gracefully
# 	descendant
# 	crowdworkers
# 	prognostic
# 	factorize
# 	flattening
# 	inductively
# 	electroencephalography
# 	releasing
# 	resilience
# 	elucidating
# 	irradiance
# 	conjugacy
# 	substantive
# Some words which never appear in Statistics papers:
# 	attentional
# 	pervasive
# 	participated
# 	experimented
# 	pheromone
# 	newspapers
# 	newspaper
# 	organizations
# 	portraits
# 	consecutively
# 	positioning
# 	compromises
# 	propagations
# 	acceptable
# 	composable
# 	susceptible
# 	monocular
# 	fixations
# 	revolutionized
# 	opaqueness

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.055300947143294e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7591666666666667
